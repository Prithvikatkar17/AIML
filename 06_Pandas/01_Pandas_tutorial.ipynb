# %%
import pandas as pd

# %%
info = {
    "name" :["rat" , "tai" ,"saty"],
    "cgpa":[9.3, 9.7,8]
}

df=pd.DataFrame(info)
print(df)
# Out:
#    name  cgpa
# 0   rat   9.3
# 1   tai   9.7
# 2  saty   8.0

# %%
df
# Out:
#    name  cgpa
# 0   rat   9.3
# 1   tai   9.7
# 2  saty   8.0
