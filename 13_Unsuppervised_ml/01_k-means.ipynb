# %%
import seaborn as sns
import sklearn.datasets import make_blobs
# Out:
#   Cell In[3], line 2
#     import sklearn.datasets import make_blobs
#                             ^
# SyntaxError: invalid syntax
