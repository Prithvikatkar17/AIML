# %%
import seaborn as sns
from sklearn.datasets import make_blobs

# %%
X , y = make_blobs(
    n_samples = 1000,
    n_features = 2,
    centers = 4,
    random_state = 42
)

# %%
# visualisation

sns.scatterplot(x=X[:, 0], y=X[:, 1] ,c=y)
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans

# %%
k = 4

# %%
kmean = KMeans(
    n_clusters = 4,
     
    random_state = 42
)

# %%
 labels =kmean.fit_predict(X)
# Out:
# C:\Users\prith\anaconda3\envs\torch_env\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1] ,c=label)
