# %%
# !pip install gymnasium
# Out:
# ...
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/953.9 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/953.9 kB ? eta -:--:--
#    -------------------- ----------------- 524.3/953.9 kB 617.8 kB/s eta 0:00:01
#    ------------------------------- ------ 786.4/953.9 kB 812.6 kB/s eta 0:00:01
#    -------------------------------------- 953.9/953.9 kB 821.0 kB/s eta 0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
# ...

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# ...
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/10.4 MB 8.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/10.4 MB 4.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/10.4 MB 4.5 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.4 MB 4.9 MB/s eta 0:00:02
#    ------------------------ --------------- 6.3/10.4 MB 6.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.3/10.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.9/10.4 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 6.5 MB/s eta 0:00:00
# ...

# %%
import gymnasium as gym
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import gymnasium as gym
#
# ModuleNotFoundError: No module named 'gymnasium'
