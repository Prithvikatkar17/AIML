# %%
conda activate torch_env
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaError: Run 'conda init' before 'conda activate'

# %%
conda init
# Out:
# no change     C:\Users\prith\anaconda3\Scripts\conda.exe
# Note: you may need to restart the kernel to use updated packages.
#
# no change     C:\Users\prith\anaconda3\Scripts\conda-env.exe
# no change     C:\Users\prith\anaconda3\Scripts\conda-script.py
# no change     C:\Users\prith\anaconda3\Scripts\conda-env-script.py
# no change     C:\Users\prith\anaconda3\condabin\conda.bat
# no change     C:\Users\prith\anaconda3\Library\bin\conda.bat
# no change     C:\Users\prith\anaconda3\condabin\_conda_activate.bat
# no change     C:\Users\prith\anaconda3\condabin\rename_tmp.bat
# no change     C:\Users\prith\anaconda3\condabin\conda_auto_activate.bat
# no change     C:\Users\prith\anaconda3\condabin\conda_hook.bat
# no change     C:\Users\prith\anaconda3\Scripts\activate.bat
# no change     C:\Users\prith\anaconda3\condabin\activate.bat
# no change     C:\Users\prith\anaconda3\condabin\deactivate.bat
# modified      C:\Users\prith\anaconda3\Scripts\activate
# ...

# %%
conda install -c conda-forge xgboost
# Out:
# Jupyter detected...
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 26.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\prith\anaconda3\envs\torch_env
#
#   added / updated specs:
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.2.25  |       h4c7d964_0         144 KB  conda-forge
#     libxgboost-3.2.0           |   cpu_h6b7513e_1         2.5 MB
#     openssl-3.6.2              |       hf411b9b_0         9.0 MB  conda-forge
# ...

# %%
import
