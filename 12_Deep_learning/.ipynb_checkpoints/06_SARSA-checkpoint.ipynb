# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in c:\users\prith\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\prith\anaconda3\lib\site-packages (from gymnasium) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\prith\anaconda3\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\prith\anaconda3\lib\site-packages (from gymnasium) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\prith\anaconda3\lib\site-packages (from gymnasium) (0.0.4)

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# Requirement already satisfied: gymnasium[toy-text] in c:\users\prith\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\prith\anaconda3\lib\site-packages (from gymnasium[toy-text]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\prith\anaconda3\lib\site-packages (from gymnasium[toy-text]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\prith\anaconda3\lib\site-packages (from gymnasium[toy-text]) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\prith\anaconda3\lib\site-packages (from gymnasium[toy-text]) (0.0.4)
# Requirement already satisfied: pygame-ce>=2.1.3 in c:\users\prith\anaconda3\lib\site-packages (from gymnasium[toy-text]) (2.5.7)

# %%
import gymnasium as gym
import numpy as np
import random

# %%
# sample env
env = gym.make("CliffWalking-v1")

# %%
print(env.observation_space.n) # states
print(env.action_space.n) # actions

starting_state, _ = env.reset() # 36 = 3 * 12 + 0
print(starting_state) # 36
# Out:
# 48
# 4
# 36

# %% [markdown]
# # SARSA
